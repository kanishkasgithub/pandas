# %% [markdown]
# Pandas Task-1

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
s1 = pd.Series([2, 4, 6, 8, 10])
s2 = pd.Series([1, 3, 5, 7, 9])
print(s1)
print(s2)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
s1 + s2
# Out:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    19
# dtype: int64

# %%
s1 - s2
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# dtype: int64

# %%
s1 * s2
# Out:
# 0     2
# 1    12
# 2    30
# 3    56
# 4    90
# dtype: int64

# %%
s1 / s2
# Out:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.111111
# dtype: float64

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
s1 = pd.Series([2, 4, 6, 8, 10])
s2 = pd.Series([1, 3, 5, 7, 10])
print('Series 1:\n',s1)
print('\nSeries 2:\n',s2)
# Out:
# Series 1:
#  0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64
#
# Series 2:
#  0     1
# 1     3
# 2     5
# 3     7
# 4    10
# dtype: int64

# %%
print('Series 1 greater than Series 2:\n',s1>s2)
print('\nSeries 1 less than Series 2:\n',s1<s2)
print('\nSeries 1 equal to Series 2:\n',s1==s2)
# Out:
# Series 1 greater than Series 2:
#  0     True
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool
#
# Series 1 less than Series 2:
#  0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
#
# Series 1 equal to Series 2:
#  0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ###`Q-4.`Write a function to change the data type of a given column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
def convert(series,data_type):
  return pd.to_numeric(series,errors='coerce').astype(data_type)

# %%
series = pd.Series([1,2,'Python', 2.0, True, 100])
series
# Out:
# 0         1
# 1         2
# 2    Python
# 3       2.0
# 4      True
# 5       100
# dtype: object

# %%
convert(series,float)
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html#pandas-to-numeric

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %%
runs = pd.read_csv('/content/batsman_runs_series.csv',index_col='batter').squeeze()
runs
# Out:
# batter
# A Ashish Reddy     280
# A Badoni           161
# A Chandila           4
# A Chopra            53
# A Choudhary         25
#                   ...
# Yash Dayal           0
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2754
# Z Khan             117
# Name: batsman_run, Length: 605, dtype: int64

# %% [markdown]
# ###`Q-5` Find top 10 most run getter from the series.

# %%
runs.sort_values(ascending=False).head(10)
# Out:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %% [markdown]
# ###`Q-6` No of players having runs above 3000

# %%
runs[runs>3000].size
# Out:
# 20

# %% [markdown]
# ###`Q-7` No of players having runs above mean value?

# %%
runs[runs>runs.mean()].size
# Out:
# 128

# %%
runs.mean()
# Out:
# 464.42809917355373

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %% [markdown]
# ###`Q-8`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     iii. Item price is given in $, so convert it to rupees without currency symbol.
#     iv. Make data type of newly made series as float.
#     v. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
# i. Read `items.csv` making `item_name` as index.
items = pd.read_csv('/content/items.csv',index_col='item_name').squeeze()
items
# Out:
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98
#                                           ...
# Steak Burrito                            $11.75
# Steak Burrito                            $11.75
# Chicken Salad Bowl                       $11.25
# Chicken Salad Bowl                        $8.75
# Chicken Salad Bowl                        $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
# ii. Show no of nan values
items.isnull().sum()
# Out:
# 50

# %%
items.isna().sum()
# Out:
# 50

# %%
# iii. Item price is given in $, so convert it to rupees without currency symbol.
items_rupees = items.astype(str).apply(lambda x:float(x.replace('$',''))*83.77)
items_rupees
# Out:
# item_name
# Chips and Fresh Tomato Salsa              200.2103
# Izze                                      283.9803
# Nantucket Nectar                          283.9803
# Chips and Tomatillo-Green Chili Salsa     200.2103
# Chicken Bowl                             1422.4146
#                                            ...
# Steak Burrito                             984.2975
# Steak Burrito                             984.2975
# Chicken Salad Bowl                        942.4125
# Chicken Salad Bowl                        732.9875
# Chicken Salad Bowl                        732.9875
# Name: item_price, Length: 4622, dtype: float64

# %%
# iv. Make data type of newly made series as float.
items_rupees.astype(float)
# Out:
# item_name
# Chips and Fresh Tomato Salsa              200.2103
# Izze                                      283.9803
# Nantucket Nectar                          283.9803
# Chips and Tomatillo-Green Chili Salsa     200.2103
# Chicken Bowl                             1422.4146
#                                            ...
# Steak Burrito                             984.2975
# Steak Burrito                             984.2975
# Chicken Salad Bowl                        942.4125
# Chicken Salad Bowl                        732.9875
# Chicken Salad Bowl                        732.9875
# Name: item_price, Length: 4622, dtype: float64

# %%
# v. Fill nan with mean of the series
items_rupees.fillna(items_rupees.mean())
# Out:
# item_name
# Chips and Fresh Tomato Salsa              200.2103
# Izze                                      283.9803
# Nantucket Nectar                          283.9803
# Chips and Tomatillo-Green Chili Salsa     200.2103
# Chicken Bowl                             1422.4146
#                                            ...
# Steak Burrito                             984.2975
# Steak Burrito                             984.2975
# Chicken Salad Bowl                        942.4125
# Chicken Salad Bowl                        732.9875
# Chicken Salad Bowl                        732.9875
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# ###`Q-9`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
# i. Find mean price
items_rupees.mean()
# Out:
# 625.1781484251968

# %%
# ii. Find 30th and 6th percentile value
items_rupees.quantile([0.3,0.06])
# Out:
# 0.30    372.7765
# 0.06    104.7125
# Name: item_price, dtype: float64

# %%
items_rupees.quantile([1,0,0.25,0.5,0.75])
# Out:
# 1.00    3706.8225
# 0.00      91.3093
# 0.25     283.9803
# 0.50     732.9875
# 0.75     774.8725
# Name: item_price, dtype: float64

# %%
# iii. Plot Histogram on price with bin size 50
items_rupees.plot(kind='hist',bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# iv. No of items price lies between [1000 to 2000]
items_rupees.between(1000,2000).sum()
# Out:
# 116

# %%
items_rupees[items_rupees.between(1000,2000)].size
# Out:
# 116

# %%
items_rupees.describe()
# Out:
# count    4572.000000
# mean      625.178148
# std       354.729356
# min        91.309300
# 25%       283.980300
# 50%       732.987500
# 75%       774.872500
# max      3706.822500
# Name: item_price, dtype: float64
